# %% [markdown]
# Name: Tiancheng Liu

# %% [markdown]
# ___
# # HW # 5

# %% [markdown]
# ____
#
# ## Problem #1 (10)
#
# In this problem you are going to explore making a parallel plot using Pandas. In general, the plotting in Pandas is not the best; but, sometimes you just want to do quick EDA only with Pandas without dealing with other libraries.
#
# 🤓 Follow these steps:
# * pick a dataset and put it into a dataframe,
# * make a parallel plot using Pandas's `parallel_coordinates`,
# * make at least two versions by choosing how you color the lines, (e.g., coloring by a categorical variable),
# * think about what conclusions you would draw about your dataset from these explorations,
# * scale the data using a z-score, and remake the parallel plot,
# * does the scaling aid in the visualization process? if so, how? if not, why not? (the answer will depend on the dataset you choose!)
#
# If you want some helper code, uncomment the code below. If you use it, comment every line and enusre that it is PEP-8 compliant.

# %%
import seaborn as sns
from scipy.stats import zscore
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
digi = pd.read_csv("digimon.csv")

# %%
digi
# Out:
#      Number            Digimon Stage     Type Attribute  Memory  Equip Slots  \
# 0         1            Kuramon  Baby     Free   Neutral       2            0
# 1         2            Pabumon  Baby     Free   Neutral       2            0
# 2         3            Punimon  Baby     Free   Neutral       2            0
# 3         4            Botamon  Baby     Free   Neutral       2            0
# 4         5            Poyomon  Baby     Free   Neutral       2            0
# ..      ...                ...   ...      ...       ...     ...          ...
# 244     245         Valkyrimon  Mega     Free      Wind      18            3
# 245     246    ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 246     247  MirageGaogamon BM  Mega     Data     Light      20            2
# 247     248         Ravemon BM  Mega  Vaccine      Wind      20            2
# 248     249         Rosemon BM  Mega     Data     Plant      20            2
#
#      Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 0         590       77        79        69        68        95
# 1         950       62        76        76        69        68
# 2         870       50        97        87        50        75
# 3         690       68        77        95        76        61
# 4         540       98        54        59        95        86
# ..        ...      ...       ...       ...       ...       ...
# 244      1330      139       148       129       129       168
# 245      1980      114       228       104        84       168
# 246      1440      124       178       104       158       174
# 247      1040      133       149       139       144       213
# 248      1480      143       149       139       159       143
#
# [249 rows x 13 columns]

# %%
pd.plotting.parallel_coordinates(digi[["Type", "Lv50 Atk", "Lv50 Spd", "Lv50 Int", "Lv50 Def"]],"Type")
# Out:
# <AxesSubplot: >

# %%
pd.plotting.parallel_coordinates(digi[["Stage", "Lv50 Atk", "Lv50 Spd", "Lv50 Int", "Lv50 Def"]],"Stage")
# Out:
# <AxesSubplot: >

# %%
pd.plotting.parallel_coordinates(digi[["Attribute", "Lv50 Atk", "Lv50 Spd", "Lv50 Int", "Lv50 Def"]],"Attribute")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ✅Conclusion: The numbers don;t depend on "attribute" or "type" but depend on "stage" more.

# %%
numeric_cols = digi.select_dtypes(include=[np.number]).columns

digi_s = digi[numeric_cols].apply(zscore)

digi_s["Stage"] = digi["Stage"]
pd.plotting.parallel_coordinates(digi_s, "Stage")
# Out:
# <AxesSubplot: >

# %%
numeric_cols = digi.select_dtypes(include=[np.number]).columns

digi_s2 = digi[numeric_cols].apply(zscore)

digi_s2["Type"] = digi["Type"]
pd.plotting.parallel_coordinates(digi_s2, "Type")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ✅No, I don't think scaling is helping, as the dataset I choose is very messy, and the data don't really vary depend on their categorical variable. But the plot with "Stage" set as color did improve a little bit.

# %%
#import seaborn as sns
#import pandas as pd
#from scipy.stats import zscore
#import numpy as np
#import matplotlib.pyplot as plt

#f, (a1,a2) = plt.subplots(ncols=2, nrows=1, figsize=(20,5))

#df_p = sns.load_dataset("penguins").dropna()

# pd.plotting.parallel_coordinates(df_p[["species", "bill_length_mm",	"bill_depth_mm",	"flipper_length_mm",	"body_mass_g"]], "species",ax=a1)

#pd.plotting.parallel_coordinates(df_p[["sex", "bill_length_mm",	"bill_depth_mm",	"flipper_length_mm",	"body_mass_g"]], "sex",ax=a1)

#numeric_cols = df_p.select_dtypes(include=[np.number]).columns

#df_p_s = df_p[numeric_cols].apply(zscore)

# df_p_s["species"] = df_p["species"]
# pd.plotting.parallel_coordinates(df_p_s, "species",ax=a2)

#df_p_s["sex"] = df_p["sex"]
#pd.plotting.parallel_coordinates(df_p_s, "sex",ax=a2)

# %% [markdown]
# ____
#
# ## Problem #2 (10)
#
# Next, we are going to compare that with HiPlot.
#
# 🤓 Follow these steps:
# * install HiPlot on your machine,
# * read the documentation to understand how to use HiPlot with a dataframe,
# * open HiPlot in your notebook with the dataset you explored in the previous problem,
# * play with HiPlot so that you know how to use its most important features:
#   * how do you select a portion of one of the vertical axes?

# %% [markdown]
# ✅Left click on the plot, drag the mouse to select a portion of the vertical axes.

# %% [markdown]
#   * how do you slide the range box vertically to select different portions of the data?

# %% [markdown]
# ✅After click and drag the mouse to select a portion of the data, a box will appear, we simplely click in the middle of the box to drag it to the desired location.

# %% [markdown]
#   * can you select (with the gray boxes) different ranges on different vertical axes?

# %% [markdown]
# ✅Yes, we can select different range of different axes.

# %% [markdown]
#   * how do you reorder the vertical axes?

# %% [markdown]
# ✅Click on the red "exclude" button to cancel selection of the vertical axes.

# %% [markdown]
#   * what use the dataframe below the plot? what happens if you mouse over the rows?

# %% [markdown]
# ✅We can click on the row in the dataframe to highlight the line it showed in the plot.

# %% [markdown]
#   * for your dataset, set the order of the vertical axes to correspond to a narrative/story, and describe that in a markdown cell - image you are using such a plot for your project and you want to tell a specific story.

# %% [markdown]
# ✅I selected the highest values in the axes "LV50 Atk" and "LV50 Spd" to see who have the top attack damage at the same time with the highest speed. As I boxed the portion of the two axes, the rows that qualifies the requirement remain in the bottom dataframe. Two rows remains in the dataframe, they are Dianamon and Leopardmon, both being in the stage Mega.

# %% [markdown]
# If you find HiPlot useful, consider using it in your project. [It works with streamlit.](https://facebookresearch.github.io/hiplot/tuto_streamlit.html)

# %%
#!pip install -U -qqq hiplot # needed for Google colab
#import hiplot as hip
#print(f"HiPlot=={hip.__version__}")

# %%
#hip.Experiment.from_dataframe(df_p).display()

# %%
import hiplot as hip
hip.Experiment.from_dataframe(digi).display()
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta http-equiv="Content-Type" content="text/html;charset=utf-8"/>
#     <title>HiPlot</title>
#     <link rel="icon" href="static/icon.png" />
#   </head>
#   <body style="margin:0px">
#     <div id="hiplot_69d683448e8c450e961292ddd5c27cf2" style="background-color: white"><div style="text-align: center">Loading HiPlot...</div>
#       <noscript>
#         HiPlot needs JavaScript to run
#       </noscript>
#     </div>
#
#     <script  type="text/javascript" ></script>
#     <script type="text/javascript">
#     function _hiplot_setup() {
#       if (typeof hiplot == "undefined") {
#         console.info("waiting for HiPlot bundle to be loaded...");
#         setTimeout(_hiplot_setup, 1000);
#         return;
#       }
#       var options = {};
#       /*ON_LOAD_SCRIPT_INJECT*/
# const comm_id = "comm_685b11";
# try {
#     console.log("Setting up communication channel with Jupyter: ", comm_id);
#     const comm = Jupyter.notebook.kernel.comm_manager.new_comm(comm_id, {'type': 'hello'});
#     var comm_message_id = 0;
#     function send_data_change(type, data) {
#         comm.send({
#             'type': type,
#             'message_id': comm_message_id,
#             'data': data,
#         });
#         comm_message_id += 1;
#     };
#     Object.assign(options, {"onChange": {
#         "selected_uids": send_data_change,
#         "brush_extents": send_data_change,
#     }});
# }
# catch(err) {
#     console.warn('Unable to create Javascript <-> Python communication channel' +
#         ' (are you in a Jupyter notebook? Jupyter labs is *not* supported!)');
# }
#
#         Object.assign(options, eval('(' + "{\"dataProviderName\": \"none\", \"experiment\": {\"parameters_definition\": {}, \"colormap\": \"interpolateTurbo\", \"colorby\": null, \"weightcolumn\": null, \"display_data\": {\"PARALLEL_PLOT\": {\"order\": [\"Number\", \"Digimon\", \"Stage\", \"Type\", \"Attribute\", \"Memory\", \"Equip Slots\", \"Lv 50 HP\", \"Lv50 SP\", \"Lv50 Atk\", \"Lv50 Def\", \"Lv50 Int\", \"Lv50 Spd\"]}, \"TABLE\": {\"order\": [\"Number\", \"Digimon\", \"Stage\", \"Type\", \"Attribute\", \"Memory\", \"Equip Slots\", \"Lv 50 HP\", \"Lv50 SP\", \"Lv50 Atk\", \"Lv50 Def\", \"Lv50 Int\", \"Lv50 Spd\"]}}, \"enabled_displays\": [\"PARALLEL_PLOT\", \"XY\", \"DISTRIBUTION\", \"TABLE\"], \"datapoints\": [{\"uid\": \"0\", \"values\": {\"Number\": 1, \"Digimon\": \"Kuramon\", \"Stage\": \"Baby\", \"Type\": \"Free\", \"Attribute\": \"Neutral\", \"Memory\": 2, \"Equip Slots\": 0, \"Lv 50 HP\": 590, \"Lv50 SP\": 77, \"Lv50 Atk\": 79, \"Lv50 Def\": 69, \"Lv50 Int\": 68, \"Lv50 Spd\": 95}, \"from_uid\": null}, {\"uid\": \"1\", \"values\": {\"Number\": 2, \"Digimon\": \"Pabumon\", \"Stage\": \"Baby\", \"Type\": \"Free\", \"Attribute\": \"Neutral\", \"Memory\": 2, \"Equip Slots\": 0, \"Lv 50 HP\": 950, \"Lv50 SP\": 62, \"Lv50 Atk\": 76, \"Lv50 Def\": 76, \"Lv50 Int\": 69, \"Lv50 Spd\": 68}, \"from_uid\": null}, {\"uid\": \"2\", \"values\": {\"Number\": 3, \"Digimon\": \"Punimon\", \"Stage\": \"Baby\", \"Type\": \"Free\", \"Attribute\": \"Neutral\", \"Memory\": 2, \"Equip Slots\": 0, \"Lv 50 HP\": 870, \"Lv50 SP\": 50, \"Lv50 Atk\": 97, \"Lv50 Def\": 87, \"Lv50 Int\": 50, \"Lv50 Spd\": 75}, \"from_uid\": null}, {\"uid\": \"3\", \"values\": {\"Number\": 4, \"Digimon\": \"Botamon\", \"Stage\": \"Baby\", \"Type\": \"Free\", \"Attribute\": \"Neutral\", \"Memory\": 2, \"Equip Slots\": 0, \"Lv 50 HP\": 690, \"Lv50 SP\": 68, \"Lv50 Atk\": 77, \"Lv50 Def\": 95, \"Lv50 Int\": 76, \"Lv50 Spd\": 61}, \"from_uid\": null}, {\"uid\": \"4\", \"values\": {\"Number\": 5, \"Digimon\": \"Poyomon\", \"Stage\": \"Baby\", \"Type\": \"Free\", \"Attribute\": \"Neutral\", \"Memory\": 2, \"Equip Slots\": 0, \"Lv 50 HP\": 540, \"Lv50 SP\": 98, \"Lv50 Atk\": 54, \"Lv50 Def\": 59, \"Lv50 Int\": 95, \"Lv50 Spd\": 86}, \"from_uid\": null}, {\"uid\": \"5\", \"values\": {\"Number\": 6, \"Digimon\": \"Koromon\", \"Stage\": \"In-Training\", \"Type\": \"Free\", \"Attribute\": \"Fire\", \"Memory\": 3, \"Equip Slots\": 0, \"Lv 50 HP\": 940, \"Lv50 SP\": 52, \"Lv50 Atk\": 109, \"Lv50 Def\": 93, \"Lv50 Int\": 52, \"Lv50 Spd\": 76}, \"from_uid\": null}, {\"uid\": \"6\", \"values\": {\"Number\": 7, \"Digimon\": \"Tanemon\", \"Stage\": \"In-Training\", \"Type\": \"Free\", \"Attribute\": \"Plant\", \"Memory\": 3, \"Equip Slots\": 0, \"Lv 50 HP\": 1030, \"Lv50 SP\": 64, \"Lv50 Atk\": 85, \"Lv50 Def\": 82, \"Lv50 Int\": 73, \"Lv50 Spd\": 69}, \"from_uid\": null}, {\"uid\": \"7\", \"values\": {\"Number\": 8, \"Digimon\": \"Tsunomon\", \"Stage\": \"In-Training\", \"Type\": \"Free\", \"Attribute\": \"Earth\", \"Memory\": 3, \"Equip Slots\": 0, \"Lv 50 HP\": 930, \"Lv50 SP\": 54, \"Lv50 Atk\": 107, \"Lv50 Def\": 92, \"Lv50 Int\": 54, \"Lv50 Spd\": 76}, \"from_uid\": null}, {\"uid\": \"8\", \"values\": {\"Number\": 9, \"Digimon\": \"Tsumemon\", \"Stage\": \"In-Training\", \"Type\": \"Free\", \"Attribute\": \"Dark\", \"Memory\": 3, \"Equip Slots\": 0, \"Lv 50 HP\": 930, \"Lv50 SP\": 64, \"Lv50 Atk\": 108, \"Lv50 Def\": 64, \"Lv50 Int\": 54, \"Lv50 Spd\": 93}, \"from_uid\": null}, {\"uid\": \"9\", \"values\": {\"Number\": 10, \"Digimon\": \"Tokomon\", \"Stage\": \"In-Training\", \"Type\": \"Free\", \"Attribute\": \"Neutral\", \"Memory\": 3, \"Equip Slots\": 0, \"Lv 50 HP\": 640, \"Lv50 SP\": 86, \"Lv50 Atk\": 76, \"Lv50 Def\": 74, \"Lv50 Int\": 74, \"Lv50 Spd\": 103}, \"from_uid\": null}, {\"uid\": \"10\", \"values\": {\"Number\": 11, \"Digimon\": \"Nyaromon\", \"Stage\": \"In-Training\", \"Type\": \"Free\", \"Attribute\": \"Light\", \"Memory\": 3, \"Equip Slots\": 0, \"Lv 50  ...

# %% [markdown]
# ____
#
# ## Problem #3 (30)
#
# It is time to start working on your project!
#
# Hopefully the HWs have prepared you to get started. Here is the schedule:
# * just a reminder: I am out of town the week of Oct. 17, but you'll have a guest instructor on probabilty and statistics; the week will be mostly normal,
# * the next week is Fall Break - we don't meet on Monday of that week,
# * your projects are due at the end of that week: in D2L by midnight on Friday, October 27th,
# * during the week of Oct. 24, you will present your projects to the other members of your class; the procedure will be:
#   * the order of presentations will be random, so you might be presenting Wed or Fri (be ready in case you are Wed! no excuses! 😉),
#   * during the presentations, you will listen to some of the presentations and interact (e.g., ask questions) with the person speaking,
#   * you will complete a report of the speakers that you listened to and turn that in (to D2L as a pdf file).
#
# You have just over two weeks! But, try to get ahead so that you can enjoy Fall Break! You deserve a rest!
#
# Here are the requirements for your project. Note that these requirements may not apply to each student perfectly, because you all have some flexibility in how you design your project. If there are any special issues with your project (e.g., the data is proprietary), please let me know so that we can work with your situation.
# * your project will be a streamlit app with two levels of interactivity:
#   * in streamlit (e.g., through sliders, dropdowns, etc.),
#   * in the visualizations themselves (e.g., using Altair or HiPlot),
#   * you must have a goal, a message, a story -- there should be a point to what you are doing,
#   * the app should contain any necessary text that aids the user to understand and explore your story,
#   * the app should be deployed to Heroku from your code at Github, and your link should be sent to Vicente by Wed before class.
#
#   A good example [is here](https://caron14-streamlit-linearregression-boston-house-prices-m9mvyd.streamlitapp.com) - try to be at least this complete in your app.
#
#   As always, please contact us, or use Slack, with any issues that arise!
#
#   🤓 For this HW, you are going to write an essay that is 500 to 1000 words. Use the [best markdown practices](https://www.markdownguide.org/cheat-sheet/), and put everything in a cell below. (You can use one plot, but no more.) What you will write is a proposal for your project. Include this in your proposal:
#   1. What is the goal, what is the point? What is the "big-picture" question you are trying to answer? Who cares? Why do they care?
#   2. Discuss which datasets you have looked at toward this goal. Which ones did you reject and why? Which dataset did you finally choose?
#   3. Describe the dataset. What is in it? Where did it come from? Are there issues, such as missingness? If so, what type (e.g., MNAR)?
#   4. What preliminary studies have you done? Do they look promising?
#   5. What will your web app do? How will this be useful to people?
#   6. What visualization tools do you plan on using? Why did you choose these? How will they serve the goal you outlined in step 1?
#   7. Summarize with why you think this is a project worthy of completing.
#
#   In your writing, use the best rules of English grammar, punctuation and formatting. Be sure you edit the proposal a few times before submitting it. It should be very clear, easy to read and convincing.

# %% [markdown]
# ✅Answer:

# %% [markdown]
# 1. The goal of my project is to explore the information hidden in datasets. Normally when we just look at a raw dataset, we couldn't find anything. Cleaning the data first will give us a first insight of what the data is about, and doing visualization allow us to dig deeper into it. My goal is to extract useful information from the four datasets I choose, so maybe I can find some interesting facts lied inside of them.
# 2. I have picked four datasets in total, the Iris dataset, MPG dataset, a dataset called Digimon, which is about a video game and the characters' specs, the last dataset I picked is a house sale price dataset, I will be using linear regression to predict the sale price of some houses with given sale price from previous house sales, the dataset contains each house's area, year of built, having garage or not, and other details about it.
# 3. Like I described in 2, Iris and MPG dataset are from package Seaborn. Digimon and house price dataset are from Kaggle, a data science competition website. All the datasets are thoroughly cleaned before passing to me, so there is no missingness. There could be potential error in the datasets, such as recording error or outliers, but so far as I look at them they do not seems to have any missing value.
# 4. I have done some visualization on the datasets, and I believe I found something to look at. For the Digimon dataset I will be using parallel_cordinates method to find the relationship of each attribute between different types of Digimon. For the house price dataset, I will be using linear regression method to find the expected price of selling for each data point in the test dataset, with given information in the training dataset. For Iris and MPG dataset, basic visualization will be done, and interesting finds will be present to the class.
# 5. One important thing that data scientists do is to present their work to someone who has no idea what data science does. Thus, my streamlit app will be able to tell someone who is completely unfamiliar with the dataset what the dataset is about, what does it tell us, what can we expect in the future when similar situation happens, or what was missing in previous decision making that we can correct in the future.
# 6. I am planning to use Altair, as it is the most powerful visualization tool I know so far, I am able to use it to make better looking plots, by what I say better looking I mean easier to understand even for a non-data-science person.
# 7. I think the most important part of this project is, we just started to learn data science and we didn't get enough chance to practice what we learned. So being able to work on our own and use what we learned in the past month will help us to understand what we are able to achieve with these tools. In the end we will use these tools to solve problems, getting conclusions and present them to people. Package utilizing, data cleaning, data visualization, getting conclusion and result presenting, the steps I will follow in the project will be the exact same steps I will follow in a future data science project.
