# %% [markdown]
# # Numbers and Datasets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ____
#
# *Name:Tiancheng liu*
#
# *Members of my group:Wenting Liu, Yuhan Zhu, Shuangyu Zhao, Yan Lyu*
# *
# *
# *
# *
# *
# ____

# %% [markdown]
# ## Instructions
#
#
#
# This assignment is due Tuesday at midnight. This is the **only** time this will happen and it is because we started on a Wednesday and have a Monday holiday.
#
# You will start today in class, but feel free to work on this with your group until Tuesday. You can use Slack for communications among your group members.
#
# ✅ Put your name and all of the names of people you worked with today in the markdown cell at the top of this notebook.
#
# There are two goals of this assignment:
# 1. to be aware of the types of data in a given dataset
# 2. to become familar with a few, very common datasets
#
# ✅ You will work as a group. 🧑🏾‍💻 Use the monitors at your station by hooking your laptops to the monitors. This allows you to work together as a team, since you are all looking at the same screen(s). You will turn in your own assignment to D2L, however, your answers do not need to be the same as the answers of other members of your group.
#
# ✅ Read through the next part of the notebook and follow the instructions. Run all of the code. If there is a problem, work with your group members or contact one of the instructors.

# %% [markdown]
# Many datasets are built into various Python libraries. You should know where you can find good datasets so they are readily available. You might also use these datasets in your projects.
#
# We will explore two sources of data in Python: Seaborn and Scikit-Learn. As you will see, these two sources are quite different!
#
# Let's look at what is built into Seaborn. We will learn *a lot* more about Seaborn later in the course; for today, just run the code and understand what is there.

# %%
# bring Seaborn in

import seaborn as sns

# %%
# this is how you get the names of the Seaborn datasets

sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File c:\Users\NamelessVirtuoso\anaconda3\lib\http\client.py:580, in HTTPResponse._readall_chunked(self)
#     579     break
# --> 580 value.append(self._safe_read(chunk_left))
#     581 self.chunk_left = 0
#
# File c:\Users\NamelessVirtuoso\anaconda3\lib\http\client.py:628, in HTTPResponse._safe_read(self, amt)
#     627 if not chunk:
# --> 628     raise IncompleteRead(b''.join(s), amt)
#     629 s.append(chunk)
#
# IncompleteRead: IncompleteRead(17804 bytes read, 17014 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# c:\Users\NamelessVirtuoso\Desktop\ICA_Fri_Sep_2_Datasets-Tiancheng Liu.ipynb Cell 7 in <cell line: 3>()
# ...

# %% [markdown]
# Read in a few datasets from Seaborn. Pay attention to this syntax and where the data is being stored.

# %%
# let's bring in a few datasets from Seaborn so that we can examine them
# --> feel free to examine others that might be interesting to your group

df_titanic = sns.load_dataset("titanic")
df_tips = sns.load_dataset("tips")
df_iris = sns.load_dataset("iris")
df_penguins = sns.load_dataset("penguins")
df_planets = sns.load_dataset("planets")

# %% [markdown]
# Many of these datasets are classics - you will encounter them many, many times.

# %% [markdown]
# ___
# Getting data from Seaborn is pretty easy. We'll get back to these datasets below.
#
# Next, you are going to bring in datasets from `sklearn`. As you will see, it is quite different from Seaborn.

# %%
from sklearn import datasets
dir(datasets)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_base',
#  '_california_housing',
#  '_covtype',
#  '_kddcup99',
#  '_lfw',
#  '_olivetti_faces',
#  '_openml',
#  '_rcv1',
#  '_samples_generator',
#  '_species_distributions',
#  '_svmlight_format_fast',
#  '_svmlight_format_io',
#  '_twenty_newsgroups',
#  'clear_data_home',
#  'dump_svmlight_file',
#  'fetch_20newsgroups',
#  'fetch_20newsgroups_vectorized',
#  'fetch_california_housing',
#  'fetch_covtype',
#  'fetch_kddcup99',
#  'fetch_lfw_pairs',
#  'fetch_lfw_people',
#  'fetch_olivetti_faces',
#  'fetch_openml',
#  'fetch_rcv1',
#  'fetch_species_distributions',
#  'get_data_home',
#  'load_boston',
#  'load_breast_cancer',
#  'load_diabetes',
#  'load_digits',
#  'load_files',
#  'load_iris',
#  'load_linnerud',
#  'load_sample_image',
#  'load_sample_images',
#  'load_svmlight_file',
#  'load_svmlight_files',
# ...

# %% [markdown]
# As you can see, there are many more datasets here. Most of these we will ignore for this class, because they are related to detailed issues in machine learning, but there are some nice datasets here that are not in Seaborn.
#
# Let's see how to load a dataset from `sklearn`. Note that what is imported is a container filled with lots of different types of information. It can look like a real mess! But, we can break out each item from the container.

# %%
datasets.load_digits()
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %% [markdown]
# What do you notice? You get a lot of output! This is because the `sklearn` datasets come with additional information. This can be super useful if you are not familiar with the dataset. But, you need to break things apart before you get started. Here is how you do that:

# %%
# actual data
# --> examine others that might be interesting to your group
digits_data = datasets.load_digits().data
wine_data = datasets.load_wine().data
# description of the data
digits_description = datasets.load_digits().DESCR
wine_description = datasets.load_wine().DESCR
# labels for the data
digits_labels = datasets.load_digits().target_names
wine_features = datasets.load_wine().feature_names

# %%
wine_features
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# ⏸ Pause for a moment and discuss within your group the differences between Seaborn and sklearn datasets. For example, what containers do they naturally use? What would you do if you needed to convert from one container to another?
#
# ✅ Add some comments to the code below to show you know what it is doing. Add a markdown cell and describe this form of data.

# %%
import matplotlib.pyplot as plt
plt.imshow(digits_data[20].reshape(8,8))

# %%
digits_data[20].reshape(8,8)
# Out:
# array([[ 0.,  0.,  3., 13., 11.,  7.,  0.,  0.],
#        [ 0.,  0., 11., 16., 16., 16.,  2.,  0.],
#        [ 0.,  4., 16.,  9.,  1., 14.,  2.,  0.],
#        [ 0.,  4., 16.,  0.,  0., 16.,  2.,  0.],
#        [ 0.,  0., 16.,  1.,  0., 12.,  8.,  0.],
#        [ 0.,  0., 15.,  9.,  0., 13.,  6.,  0.],
#        [ 0.,  0.,  9., 14.,  9., 14.,  1.,  0.],
#        [ 0.,  0.,  2., 12., 13.,  4.,  0.,  0.]])

# %%
#After some tests on the function's command, we found that: it first extract the 20th element from the array digits_data
#Then reshape the 20th element, which is an array, to a 8x8 matrix
#Then use the command "imshow" to plot the matrix, which is a set of floats
#on the plot, The larger the number, the brighter the color

# %% [markdown]
# We just read the Seaborn data into Pandas dataframes.
#
# We can view the dataframe by just putting the dataframe name into a cell and using shift-enter:

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# We can also get quick statistics using `describe`:

# %%
df_planets.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %% [markdown]
# ✅ Pick 4 Seaborn datasets and answer these questions for all 4:
# * how many columns are there in that dataset?
# * what is in each column? that is: real? ordinal? category? nominal?
# * in the first line from `describe`, you have the count - for each of the three datasets you picked, is the count the same for each column? if not, why not?
# * do you see any NaNs in any of your datasets?
# * when you use `describe`, what does Pandas do with columns for which the mean and std don't make any sense?

# %%
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_titanic.isnull().values.any()
# Out:
# True

# %%
#In the titanic dataset, we have 15 columns, 
#columns describing the information of each survivor survived the Titanic crash
#Count are not always the same because some informtion in the dataset is missing
#Yes there are NaNs in the dataset
#Some "numbers" are not intergers or floats, so taking the mean an std of them doesn't make sense

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df_tips.isnull().values.any()
# Out:
# False

# %%
#In the tips dataset, we have 7 columns, 
#Columns in the dataset represent the tips given by the cumstomers, and the charactistics of different customer
#Count are the same
#No there are no NaN in this dataset
#"Size" in more likely a categorical variable rather than a numerical variable, so taking the mean and std doesn't make sense

# %%
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df_iris.isnull().values.any()
# Out:
# False

# %%
#In the iris dataset, we have 5 columns, 
#columns describing the information of different species of iris, their length and width, etc.
#Count are the same
#No there are not
#The means and stds all make sense because these columns are all numerical variables.

# %%
df_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df_penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df_penguins.isnull().values.any()
# Out:
# True

# %%
#In the penguins dataset, we have 7 columns, 
#columns describing the information of species of penguins, where do they live, there body shape and other characteristic.
#Count are the same
#No there are not
#The means and stds all make sense because these columns are all numerical variables.

# %% [markdown]
# ✅ Within your group, discuss what _message_ each of these datasets has. That is, just by looking at the data, what can you infer about what it might be able to tell you? Summarize that message for three datasets:
#
# 1. message for penguins is : *Even being the same specie, penguins living in different islands tend to show different body charcteristics.*
# 2. message for iris is : *Different species of iris are identical to each other.*
# 3. message for tips is : *Tips vary in different situations, time, smoker or not, their sex and weekday or not can all influence the tips given by one person.*
# 4. message for titanic is : *Most of the survivors were coming from upper class seats.*

# %% [markdown]
# ✅ Next, visualize your datasets. Choose 4 of your favorite Seaborn datasets and use `pairplot` to explore your data. Go to this [website](https://seaborn.pydata.org/generated/seaborn.pairplot.html) and see what the options are. Try several options.
#
# ✅ Answer these questions after each plot:
# * what do you see along the diagonal?
# * what do you see in the off-diagonal panels?
# * for each dataset, do you see a clearer message appearing? what is that message?

# %%
# here is an example for the penguin dataset
sns.pairplot(df_penguins, hue="island")

# %%
sns.pairplot(df_iris, hue = "species")

#on the diagnal I see the distribution of each variable
#on the off-diagnal panels I see the relationsip between length and width
#generally, the longer the sepal the wider the sepal. Setosa has an overall pedal size than the
#other two species

# %%
sns.pairplot(df_planets, hue = "method")


#on the diagnal I see the distribution of each variable
#on the off-diagnal panels I see the relationsip between different variables
#Not so much information can be obtained from the pairplot. One thing I can see now is that
#Most of the information gathered in this dataset is using the method "Radial Velocity"

# %%
sns.pairplot(
    df_titanic,
    x_vars=["who", "fare", "alive"],
    y_vars=["alone", "age"], hue = "class"
)

#Since I set the x and y variables, there is no "diagnal" here
#The off-diagnal panel shows the relationship between their characteristic and their survival rate
#I can see from the pairplots that We ave more male passenger than female passenger
#Most of the survivors came from upper class and are female

# %%
sns.pairplot(df_tips, 
             hue="sex", 
             markers=["o", "s"], 
            x_vars= ["total_bill","day","time"],
            y_vars = ["tip","smoker"])


#Since I set the x and y variables, there is no "diagnal" here
#The off-diagnal panel shows the relationship between customer characteristics and their tip amount
#I can see from the pairplots that, male customer generally gives more tips
#On Saturday customer gives more tips
#Dinner time tips are usually higher than lunch time tips

# %% [markdown]
# Please fill out the form to help us understand the python experiences among the students and evaluate the need for python boot camps: https://forms.gle/Aq1nUHqo9ooWET9U9

# %% [markdown]
# _____
#
# 👍🏻
#
# Congrats! You have reached the end.
#
# Don't forget to put your name at the top, and the names of the people you worked with.
#
# Upload the notebook into D2L. If you have any trouble, contact Vicente through Slack.
#
# This is due at midnight on Tuesday. Enjoy your Monday holiday!
